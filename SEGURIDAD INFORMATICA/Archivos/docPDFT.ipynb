# %%
import PyPDF2

def leer_pdf(nombre_archivo):
    with open(nombre_archivo, 'rb') as archivo:
        lector_pdf = PyPDF2.PdfReader(archivo)
        num_paginas = len(lector_pdf.pages)
        contenido = ''
        for pagina in range(num_paginas):
            texto = lector_pdf.pages[pagina].extract_text()
            contenido += texto
    return contenido

# Uso
contenido_pdf = leer_pdf('Archivo1.pdf')
print(contenido_pdf)
# Out:
#
#
# PLANEACIÓN DEL PROYECTO
# DE CÁTALOGO DE ZONAS
# ARQUEOLOGICAS DE M ÉXICO
# Metodologías  para el desarrollo de proyectos  Integrantes del equipo:
# José Rubén Estrada García
# Luis Fernando Fuentes Kumul
# Katherine Florio Ramos
# Julio José Flores Alamilla
#
# Grupo: IDYGS71
# Fecha de entrega:  06/11/2023
#
# Alcance del Proyecto:
# El objetivo es desarrollar una aplicación móvil para dispositivos Android en la cual
# se implementa rá un catálogo interactivo para explorar y conocer las zonas
# arqueológicas de diversos estados en México  que proporciona rá una breve
# descripción  por c ada zona  arqueológica , incluyendo imágenes de referencia  y
# ubicación  geográfica .
# Objetivos específ icos:
# 1. Planeación d el proyecto , definir o bjetivo general y objetivos  específicos .
# 2. Recopilar y documentar todas  las zonas arqueológicas existentes en la
# República para crear un inventario completo.
# 3. Diseñar una interfaz para el  usuario que sea amigable y dinámica .
# 4. Impleme ntar herramientas que le facilite al usuario la búsqueda  de las zonas
# arqueológicas  que especifique .
# 5. Ajustes y mejoras del proyecto
# 6. Cierr e del proyecto
# Entregables:
# • Documentación del proyecto.
# • Código fuente de la aplicación móvil.
# • Aplicación móvil funcional.
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Lista de zonas arqueológicas  a implementar :
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#  Nuevo León
# Oaxaca
# Puebla
# Querétaro
# Quintana Roo
# San Luis Potosí
# Sinaloa
# Sonora
# Tabasco
# Tamaulipas
# Tlaxcala
# Veracruz
# Yucatán
#  Zacatecas
#  Baja California
# Baja California Sur
# Campeche
# Chiapas
# Chihuahua
# CDMX
# Coahuila
# Colima
# Durango
# Estado de México
# Guanajuato
# Guerrero
# Hidalgo
# Jalisco
# Michoacán
# Morelos
# Nayarit
#
# Cronograma de actividades :
#
# Cronograma de actividades
# Título del proyecto:  catálogo  de zonas arqueologías  de México
# Objetivo General:  El objetivo es desarrollar una aplicación móvil para dispositivos Android
# en la cual se implementará un catálogo interactivo para explorar y
# conocer las zonas arqueológicas de diversos estados en México que
# proporcionará una breve descripción por cada zona  arqueológica,
# incluyendo imágenes de referencia y ubicación geográfica.
# Objetivos específicos  actividades  Novi embre  Diciembre  Enero  Febrero
# Planeación del
# proyecto, definir
# objetivo general y
# objetivos específicos.  Planificación del
# proyecto,
# definición de
# roles, objetivos y
# entregables
# Recopilar y documentar
# todas las zonas
# arqueológicas
# existentes en la
# República para crear un
# inventario completo.  Categorizar cada
# una de las zonas
# arqueológicas
# que hay por
# estad o para el
# llenado de
# información de
# cada vista .
#
#
#
#  Implementar
# diseño visual a la
# aplicación móvil a
# desarrollar, como
# paletas de
# colores, vista
# principales ,etc.
# Diseño de la Interfaz de
# Usuario   Desarrollar vistas
# en el front para
# cada uno de los
# estados de la
# república en
# donde incluya
# información
# detallada de cada
# zona
# arqueológica,
# como mapas,
# fotografías y
# descripciones .
#
#
#
# -     Implementar
# herramientas que le
# facilite al usuario la
# búsqueda de las zonas
# arqueológicas que
# especifique.  Se implementa n
# cuadros de
# búsqueda  o
# dashboard que
# acomoden las
# zonas
# arqueológicas  en
# orden de acu erdo
# al estado al q ue
# pertenece .
# Ajustes y Mejoras  Correcciones
# basadas en
# retroalimentación,
# optimización
# Cierre del Proyecto  Evaluación del
# proyecto,
# documentación
# final, reunión de
# cierre
